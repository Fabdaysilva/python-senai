# %%
# Importar Bibliotecas

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# %%
dir_path = 'C:\\Users\\FIC\\Documents\\Fabiana Python\\003 - Arquivos\\005 - Desafios-20230929T215633Z-001\\arquivos\\vendas\\'
os.listdir(dir_path) #Viasualiza todos os arquivos do caminho

res = []

for path in os.listdir(dir_path):
    #Verificar se é um arquivo válido
    if os.path.isfile(dir_path + path):
        res.append(dir_path + path)

file_combined =pd.DataFrame()

for file in res:
    df1 = pd.read_excel(file)
    file_combined = pd.concat([file_combined, df1])

dir_final = 'C:\\Users\\FIC\Documents\\Fabiana Python\\003 - Arquivos\\005 - Desafios-20230929T215633Z-001\\arquivos\\'
fileName = 'ArquivoVendasCombinado.xlsx'

file_combined.to_excel(dir_final + fileName)

# %%
file_combined.head()
# Out:
#   DataEmissao DataVencimento      NFe  cdCliente  cdVendedor  cdProduto  \
# 0  2017-01-12     2017-02-22  1492762    3140218         265       1073
# 1  2017-01-12     2017-02-22  1492762    3140218         265       1420
# 2  2017-01-12     2017-02-22  1492762    3140218         265        264
# 3  2017-01-13     2017-01-29  1492719    2983332         265       1154
# 4  2017-01-13     2017-01-29  1492719    2983332         265       1527
#
#    QtdItens  ValorUnitario  Peso Líquido
# 0         6           8.83          0.60
# 1         6           4.44          5.40
# 2        10           0.96          1.92
# 3         6           2.92          1.26
# 4         6           2.81          1.40

# %% [markdown]
# #### Importando as tabelas dimensões (DE-PARA)

# %%
# Carregar a tabela de clientes
path = 'C:\\Users\\FIC\\Documents\\Fabiana Python\\003 - Arquivos\\005 - Desafios-20230929T215633Z-001\\arquivos\\'
file = 'Dimensões.xlsx'

#Alocar o documento em um Datafreme

dfcliente = pd.read_excel(path + file, sheet_name= 'Cliente')

# Visualizar o cabeçalho dos dados

dfcliente.head()
# Out:
#    cdCliente                   Razão Social Status Categoria    Cidade  UF
# 0    1339104   Vinicius e Filipe Cantina ME      A  Cantinas  Curitiba  PR
# 1    1339740  Sandra e Cláudio Cantina Ltda      A  Cantinas  Curitiba  PR
# 2    1339884        Vera e Analu Cantina ME      A  Cantinas  Curitiba  PR
# 3    1340322    Emilly e Vitor Cantina Ltda      A  Cantinas  Curitiba  PR
# 4    4837795    Kaique e Rafaela Cantina ME      A  Cantinas  Curitiba  PR

# %%
# Carregar a tabela de Produto
path = 'C:\\Users\\FIC\\Documents\\Fabiana Python\\003 - Arquivos\\005 - Desafios-20230929T215633Z-001\\arquivos\\'
file = 'Dimensões.xlsx'

#Alocar o documento em um Datafreme

dfproduto = pd.read_excel(path + file, sheet_name= 'Produto')

# Visualizar o cabeçalho dos dados

dfproduto.head()
# Out:
#    cdProduto  Descrição  cdGrupo
# 0          1  Produto 1     9999
# 1          2  Produto 2     9999
# 2          3  Produto 3     9999
# 3          4  Produto 4     9999
# 4          5  Produto 5     9999

# %%
# Carregar a tabela de Grupo produto
path = 'C:\\Users\\FIC\\Documents\\Fabiana Python\\003 - Arquivos\\005 - Desafios-20230929T215633Z-001\\arquivos\\'
file = 'Dimensões.xlsx'

#Alocar o documento em um Datafreme

dfgrupoProduto = pd.read_excel(path + file, sheet_name= 'GrupoProduto')

# Visualizar o cabeçalho dos dados

dfgrupoProduto.head()
# Out:
#    cdGrupo            Grupo      Linha
# 0      102      Leite em Pó  Alimentos
# 1      103         Açúcares  Alimentos
# 2      104  Doces Enlatados  Alimentos
# 3      105         Farinhas  Alimentos
# 4      106            Óleos  Alimentos

# %%
# Carregar a tabela de vendedor
path = 'C:\\Users\\FIC\\Documents\\Fabiana Python\\003 - Arquivos\\005 - Desafios-20230929T215633Z-001\\arquivos\\'
file = 'Dimensões.xlsx'

#Alocar o documento em um Datafreme

dfvendedor = pd.read_excel(path + file, sheet_name= 'Vendedor')

# Visualizar o cabeçalho dos dados

dfvendedor.head()
# Out:
#    cdVendedor          Vendedor  cdSupervisor      Supervisor  cdGerente  \
# 0         669       Kaua Araujo            15  Fernando Silva          1
# 1         660     Julieta Gomes            25     Emily Rocha          1
# 2         183    Isabella Sousa            25     Emily Rocha          1
# 3         102    Gustavo Barros            25     Emily Rocha          1
# 4         196  Leonardo Cardoso            30    Diego Araujo          1
#
#          Gerente  Equipe
# 0  Victor Castro  Varejo
# 1  Victor Castro  Varejo
# 2  Victor Castro  Varejo
# 3  Victor Castro  Varejo
# 4  Victor Castro  Varejo

# %%
# Carregar a tabela de data
path = 'C:\\Users\\FIC\\Documents\\Fabiana Python\\003 - Arquivos\\005 - Desafios-20230929T215633Z-001\\arquivos\\'
file = 'Dimensões.xlsx'

#Alocar o documento em um Datafreme

dfdata = pd.read_excel(path + file, sheet_name= 'Data')

# Visualizar o cabeçalho dos dados

dfdata .head()
# Out:
#         Data   Ano      Mes  MesNum  Dia
# 0 2017-01-01  2017  Janeiro       1    1
# 1 2017-01-02  2017  Janeiro       1    2
# 2 2017-01-03  2017  Janeiro       1    3
# 3 2017-01-04  2017  Janeiro       1    4
# 4 2017-01-05  2017  Janeiro       1    5

# %%
# Carregar a tabela de Metas
path = 'C:\\Users\\FIC\\Documents\\Fabiana Python\\003 - Arquivos\\005 - Desafios-20230929T215633Z-001\\arquivos\\'
file = 'Metas.xlsx'

#Alocar o documento em um Datafreme

dfmetas = pd.read_excel(path + file)

# Visualizar o cabeçalho dos dados

dfmetas .head()
# Out:
#    Unnamed: 0              Metas por Vendedor           Unnamed: 2  \
# 0         NaN  Última Atualização: 31/12/2019                  NaN
# 1         NaN                             NaN                  NaN
# 2         NaN                             NaN                  NaN
# 3         NaN                      cdVendedor  2017-01-01 00:00:00
# 4         NaN                             102        140768.312981
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3  2017-02-01 00:00:00  2017-03-01 00:00:00  2017-04-01 00:00:00
# 4        124258.753484        169509.931262        143465.231352
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3  2017-05-01 00:00:00  2017-06-01 00:00:00  2017-07-01 00:00:00
# 4         98423.627768        133401.861987        109124.992168
#
#             Unnamed: 9  ...          Unnamed: 64          Unnamed: 65  \
# 0                  NaN  ...                  NaN                  NaN
# 1                  NaN  ...                  NaN                  NaN
# 2                  NaN  ...                  NaN                  NaN
# 3  2017-08-01 00:00:00  ...  2022-03-01 00:00:00  2022-04-01 00:00:00
# 4        221597.228027  ...                98801                72820
#
#            Unnamed: 66          Unnamed: 67          Unnamed: 68  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3  2022-05-01 00:00:00  2022-06-01 00:00:00  2022-07-01 00:00:00
# 4                62828                23732                59726
#
#            Unnamed: 69          Unnamed: 70          Unnamed: 71  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3  2022-08-01 00:00:00  2022-09-01 00:00:00  2022-10-01 00:00:00
# 4                72648                90886                33627
#
#            Unnamed: 72          Unnamed: 73
# 0                  NaN                  NaN
# 1                  NaN                  NaN
# 2                  NaN                  NaN
# 3  2022-11-01 00:00:00  2022-12-01 00:00:00
# 4                22575               147200
#
# [5 rows x 74 columns]

# %%
# Carregar a tabela de data
path = 'C:\\Users\\FIC\Documents\\Fabiana Python\\003 - Arquivos\\005 - Desafios-20230929T215633Z-001\\arquivos\\'
file = 'ArquivoVendasCombinado.xlsx'

#Alocar o documento em um Datafreme

dfvendas = pd.read_excel(path + file)

# Visualizar o cabeçalho dos dados

dfvendas.head()
# Out:
#    Unnamed: 0 DataEmissao DataVencimento      NFe  cdCliente  cdVendedor  \
# 0           0  2017-01-12     2017-02-22  1492762    3140218         265
# 1           1  2017-01-12     2017-02-22  1492762    3140218         265
# 2           2  2017-01-12     2017-02-22  1492762    3140218         265
# 3           3  2017-01-13     2017-01-29  1492719    2983332         265
# 4           4  2017-01-13     2017-01-29  1492719    2983332         265
#
#    cdProduto  QtdItens  ValorUnitario  Peso Líquido
# 0       1073         6           8.83          0.60
# 1       1420         6           4.44          5.40
# 2        264        10           0.96          1.92
# 3       1154         6           2.92          1.26
# 4       1527         6           2.81          1.40

# %%
# valor faturamento
dfvendas.ValorUnitario.sum()
# Out:
# 2077072.8300000005

# %% [markdown]
# #### Questão 02
# ##### clientes por ano

# %%
file_combined.head()
# Out:
#   DataEmissao DataVencimento      NFe  cdCliente  cdVendedor  cdProduto  \
# 0  2017-01-12     2017-02-22  1492762    3140218         265       1073
# 1  2017-01-12     2017-02-22  1492762    3140218         265       1420
# 2  2017-01-12     2017-02-22  1492762    3140218         265        264
# 3  2017-01-13     2017-01-29  1492719    2983332         265       1154
# 4  2017-01-13     2017-01-29  1492719    2983332         265       1527
#
#    QtdItens  ValorUnitario  Peso Líquido
# 0         6           8.83          0.60
# 1         6           4.44          5.40
# 2        10           0.96          1.92
# 3         6           2.92          1.26
# 4         6           2.81          1.40

# %%
dfdata.head()
# Out:
#         Data   Ano      Mes  MesNum  Dia
# 0 2017-01-01  2017  Janeiro       1    1
# 1 2017-01-02  2017  Janeiro       1    2
# 2 2017-01-03  2017  Janeiro       1    3
# 3 2017-01-04  2017  Janeiro       1    4
# 4 2017-01-05  2017  Janeiro       1    5

# %%
# Bloco utilizado para combinar as colunas ANO, Mês, Dia e Mesnum do dataframe
#dfData, para que seja possivel agregar os dados de modo a visualizar as informações 
# por ano

df_clienteano = file_combined.merge(dfdata, #tabela da direita (fornecedora das colunas faltantes)
                                    left_on= 'DataEmissao', #coluna que será utilizada como valor procurando na tabela esq
                                    right_on='Data', #coluna da tabela da direita que será utilizada para busca
                                    how='left' # É a forma que os dados serão inseridos, ESQUERDA <--- DIREITA
                                    )

df_clienteano
# Out:
#        DataEmissao DataVencimento      NFe  cdCliente  cdVendedor  cdProduto  \
# 0       2017-01-12     2017-02-22  1492762    3140218         265       1073
# 1       2017-01-12     2017-02-22  1492762    3140218         265       1420
# 2       2017-01-12     2017-02-22  1492762    3140218         265        264
# 3       2017-01-13     2017-01-29  1492719    2983332         265       1154
# 4       2017-01-13     2017-01-29  1492719    2983332         265       1527
# ...            ...            ...      ...        ...         ...        ...
# 302835  2022-03-12     2022-04-14  2173547     673190         265        202
# 302836  2022-03-12     2022-04-14  2173547     673190         265       1154
# 302837  2022-03-12     2022-04-14  2173547     673190         265        668
# 302838  2022-03-12     2022-04-14  2173547     673190         265       1527
# 302839  2022-03-13     2022-04-05  2172961    3771379         215        257
#
#         QtdItens  ValorUnitario  Peso Líquido       Data   Ano      Mes  \
# 0              6           8.83          0.60 2017-01-12  2017  Janeiro
# 1              6           4.44          5.40 2017-01-12  2017  Janeiro
# 2             10           0.96          1.92 2017-01-12  2017  Janeiro
# 3              6           2.92          1.26 2017-01-13  2017  Janeiro
# 4              6           2.81          1.40 2017-01-13  2017  Janeiro
# ...          ...            ...           ...        ...   ...      ...
# 302835        24           1.62          1.50 2022-03-12  2022    Março
# 302836        12           3.25          1.75 2022-03-12  2022    Março
# 302837        12           3.26          1.00 2022-03-12  2022    Março
# 302838        12           3.14          1.00 2022-03-12  2022    Março
# 302839         6           4.42          1.20 2022-03-13  2022    Março
#
#         MesNum  Dia
# 0            1   12
# 1            1   12
# 2            1   12
# 3            1   13
# 4            1   13
# ...        ...  ...
# 302835       3   12
# 302836       3   12
# 302837       3   12
# 302838       3   12
# 302839       3   13
#
# [302840 rows x 14 columns]

# %%
# Cria um novo dataframe, considerando apenas as colunas ANO e cdCliente do file_combined
df_contagem_cliente = df_clienteano.loc[:,['Ano','cdCliente']]

# Remover a duplicada para calcular a cobertura de clientes
# Sendo que para este cálculo é necessário eliminar os registros
# Duplicados, considera todas as colunas

df_contagem_cliente= df_contagem_cliente.drop_duplicates()

# Agrupa os dados, por meio de contagem, separando os dados
# através da coluna ANO
df_contagem_cliente = df_contagem_cliente.groupby(['Ano']).count()

# %%
df_contagem_cliente.head()
# Out:
#       cdCliente
# Ano
# 2017        599
# 2018       1232
# 2019        980
# 2020        980
# 2021        980

# %%
sns.barplot(x= df_contagem_cliente.index, 
            y= 'cdCliente',
            data=df_contagem_cliente)
# Out:
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Ano', ylabel='cdCliente'>

# %% [markdown]
# #### 3. Peso líquido total vendidos por ano?

# %%
# Criando um novo dataframe com as colunas ano e Peso liquido
df_peso_ano = df_clienteano.loc[:,['Ano','Peso Líquido']]

df_peso_ano = df_peso_ano.groupby('Ano').sum()

df_peso_ano["Peso_tons"] = df_peso_ano['Peso Líquido']/1000

df_peso_ano
# Out:
#       Peso Líquido  Peso_tons
# Ano
# 2017     414819.40  414.81940
# 2018     658505.01  658.50501
# 2019      61465.62   61.46562
# 2020      61465.62   61.46562
# 2021      61465.62   61.46562
# 2022      61465.62   61.46562

# %% [markdown]
# #### 4. Qual é Total de Faturamento da Super Atacadista em todo o período?

# %%
graficos = sns.barplot(x= df_peso_ano.index,
                       y= df_peso_ano['Peso_tons'],
                       )
# Titulo Gráfico
plt.title ('Peso em Toneladas por Ano', fontsize = 18, c='purple')

# titulo mo eixo Y
plt.ylabel('Peso (tons)')

# titulo mo eixo x
plt.xlabel('Ano')

# Rótulo nas coluns do gráfico
graficos.bar_label(graficos.contains[0])
# Out:
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\FIC\Documents\Fabiana Python\Aula 131 - Desafio.ipynb Cell 23 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/FIC/Documents/Fabiana%20Python/Aula%20131%20-%20Desafio.ipynb#X31sZmlsZQ%3D%3D?line=10'>11</a> plt.xlabel('Ano')
#      <a href='vscode-notebook-cell:/c%3A/Users/FIC/Documents/Fabiana%20Python/Aula%20131%20-%20Desafio.ipynb#X31sZmlsZQ%3D%3D?line=12'>13</a> # Rótulo nas coluns do gráfico
# ---> <a href='vscode-notebook-cell:/c%3A/Users/FIC/Documents/Fabiana%20Python/Aula%20131%20-%20Desafio.ipynb#X31sZmlsZQ%3D%3D?line=13'>14</a> graficos.bar_label(graficos.contains[0])
#
# TypeError: 'method' object is not subscriptable

# %%
df_fat = df_clienteano.loc[:,['Ano','QtdItens','ValorUnitario']]

# Adicionando a coluna Subtotal
df_fat['subtotal'] = df_fat['QtdItens'] * df_fat['ValorUnitario']

# Calcular o total vendido no período
df_fat = df_fat.loc[:,['Ano','subtotal']]

df_fat = df_fat.groupby('Ano').sum() / (10 ** 6)

df_fat
# Out:
#        subtotal
# Ano
# 2017   6.648222
# 2018  10.214809
# 2019   1.046201
# 2020   1.046201
# 2021   1.046201
# 2022   1.046201

# %%
# Criando gráfico de colunas
sns.barplot(x = df_fat.index, y = df_fat['subtotal'])
# Out:
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Ano', ylabel='subtotal'>

# %% [markdown]
# #### 5. Qual foi a quantidade total de produtos vendidos em todo o período?
# (Crie um gráfico de colunas para mostrar o total vendido por ano)

# %% [markdown]
# #### 7. Quantos clientes ativos e inativos temos em nossa empresa?
# (Crie um gráfico de rosca para mostrar estes totais)

# %%
#Selecionando as colunas cdClientes e Status do dataframe dfclinete

dfclientes_resumo = dfcliente.loc[:,['cdCliente','Status']]

# substituir os valores na coluna status 
# A - Ativo I - Inativo


dfclientes_resumo['Status'] = dfclientes_resumo['Status'].replace('A','Ativo')
dfclientes_resumo['Status'] = dfclientes_resumo['Status'].replace('I','Inativo')

#agrupar os dados por Ativo e Inativo

dfclientes_resumo = dfclientes_resumo.groupby('Status').count()
dfclientes_resumo
# Out:
#          cdCliente
# Status
# Ativo         1364
# Inativo         47

# %%
# Criando gráfico de colunas
sns.barplot(y = dfclientes_resumo.index, x = dfclientes_resumo['Status'])
# Out:
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Status'>

# %%
# Gráfico de pizza
plt.pie(dfclientes_resumo['cdCliente'], #Valores do gráfico
        labels= dfclientes_resumo.index, #Rótulos de dados
        autopct='%.0f%%')                # Exibir os valores em porcentagem
# Out:
# ([<matplotlib.patches.Wedge at 0x2756a870410>,
#   <matplotlib.patches.Wedge at 0x2756a809550>],
#  [Text(-1.0939826195114473, 0.11490007922918268, 'Ativo'),
#   Text(1.093982623545592, -0.11490004081941627, 'Inativo')],
#  [Text(-0.5967177924607893, 0.06267277048864509, '97%'),
#   Text(0.596717794661232, -0.0626727495378634, '3%')])

# %% [markdown]
# #### 6. Qual foi o total de peso em toneladas dos produtos vendidos em todo o período?
# (Crie um gráfico de colunas para mostrar o total vendido por ano)

# %%
df_peso_ano['Peso_tons'].sum()
#df_peso_ano = round(df_peso_ano,2)

#print(f'O peso total vendido foi de {df_peso_ano} toneladas'.)
#round (valor, numero de digitos_)
# Out:
# 1319.21

# %% [markdown]
# #### 8. Qual foi o ano com maior ticket médio dos produtos?
# (Ticket médio = Total faturado pela quantidade vendida)

# %%
#Seleção das colunas Ano, QtdeItens e Valor Unitário
df_ticket = df_clienteano.loc[:,['Ano','QtdItens','ValorUnitario']]

# Adicionar a coluna Valor Total
df_ticket['ValorTotal'] = df_ticket['QtdItens'] * df_ticket['ValorUnitario']

# Selecionar as colunas de interesse
df_ticket = df_ticket.loc[:,['Ano','QtdItens','ValorTotal']]

# Agrupar os campos QtdeItens e ValorTotal por Ano
df_ticket = df_ticket.groupby('Ano').sum()

# Adicionar a coluna Ticket Médio, com base no cálculo 
# Valor total / Qtde Itens por ano
df_ticket['Ticket Medio'] = df_ticket['ValorTotal'] / df_ticket['QtdItens']

df_ticket
# Out:
#       QtdItens   ValorTotal  Ticket Medio
# Ano
# 2017   2167345   6648222.05      3.067450
# 2018   3864838  10214809.43      2.643011
# 2019    348989   1046201.01      2.997805
# 2020    348989   1046201.01      2.997805
# 2021    348989   1046201.01      2.997805
# 2022    348989   1046201.01      2.997805
