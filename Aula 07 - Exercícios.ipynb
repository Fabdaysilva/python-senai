# %% [markdown]
# ### Exercício 02 – Manipulando dados com Pandas
#
# ### a) Crie um programa em pandas para ler o arquivo em Excel imobiliária.xlsx
# ### b) e coloque em um dataframe.
# ### c) Visualize o cabeçalho dos dados;
# ### d) Visualize as últimas linhas;
# ### e) Escreva um programa para renomear o cabeçalho da tabela com os

# %%
import pandas as pd

caminho = 'C:\\Users\\FIC\Documents\\Fabiana Python\\003 - Arquivos\\'
arquivo = 'Imobiliária.xlsx'

df = pd.read_excel(caminho + arquivo, sheet_name= 'Base')

df.head()
# Out:
#    Coluna 1  Coluna 2   Coluna 3     Coluna 4  Coluna 5  Coluna 6  Coluna 7  \
# 0    Centro    Simone 2005-10-08  Apartamento     102.5         2         2
# 1  Noroeste    Simone 2005-10-08  Apartamento     199.5         4         4
# 2     Norte   Roberto 2005-10-12         Casa     145.5         2         2
# 3   Sudeste    Simone 2005-10-14  Apartamento     153.5         3         2
# 4  Noroeste  Cristina 2005-10-16  Apartamento      93.0         2         2
#
#   Coluna 8  Coluna 8.1  Coluna 10
# 0      Sim      235500     3532.5
# 1      Não      377700     5665.5
# 2      Não      232500     3487.5
# 3      Não      289100     4336.5
# 4      Sim      235400     3531.0

# %%
df.tail()
# Out:
#      Coluna 1     Coluna 2   Coluna 3     Coluna 4  Coluna 5  Coluna 6  \
# 1112  Sudeste     Cristina 2011-03-19  Apartamento      87.5         2
# 1113  Sudeste       Simone 2011-03-20  Apartamento      74.5         2
# 1114    Norte  João Carlos 2011-03-21  Apartamento     192.0         4
# 1115    Leste       Simone 2011-03-27  Apartamento      42.0         1
# 1116    Oeste       Simone 2011-03-28  Apartamento     100.5         2
#
#       Coluna 7 Coluna 8  Coluna 8.1  Coluna 10
# 1112         0      Não      221500     3322.5
# 1113         2      Não      224400     3366.0
# 1114         4      Não      361000     5415.0
# 1115         1      Sim      167900     2518.5
# 1116         2      Sim      227600     3414.0

# %% [markdown]
# ### e) Escreva um programa para renomear o cabeçalho da tabela com os

# %%
df.columns = ['filial','vendedor','Data','tipo','area','dorms','garag','piscina','preço','comissão']

df.head()
# Out:
#      filial  vendedor       Data         tipo   area  dorms  garag piscina  \
# 0    Centro    Simone 2005-10-08  Apartamento  102.5      2      2     Sim
# 1  Noroeste    Simone 2005-10-08  Apartamento  199.5      4      4     Não
# 2     Norte   Roberto 2005-10-12         Casa  145.5      2      2     Não
# 3   Sudeste    Simone 2005-10-14  Apartamento  153.5      3      2     Não
# 4  Noroeste  Cristina 2005-10-16  Apartamento   93.0      2      2     Sim
#
#     preço  comissão
# 0  235500    3532.5
# 1  377700    5665.5
# 2  232500    3487.5
# 3  289100    4336.5
# 4  235400    3531.0

# %% [markdown]
# ### g) 5. Quais são os tipos de dados que temos no dataframe?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1117 entries, 0 to 1116
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filial    1117 non-null   object
#  1   vendedor  1117 non-null   object
#  2   Data      1117 non-null   datetime64[ns]
#  3   tipo      1117 non-null   object
#  4   area      1117 non-null   float64
#  5   dorms     1117 non-null   int64
#  6   garag     1117 non-null   int64
#  7   piscina   1117 non-null   object
#  8   preço     1117 non-null   int64
#  9   comissão  1117 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(4)
# memory usage: 87.4+ KB

# %% [markdown]
# ### i) Calcule a soma, média, máximo, mínimo e contagem da coluna Preço.

# %%
print('O valor total é:', df['preço'].sum())
print('A média dos valores é:', df['preço'].mean())
print('O Maior valor é:', df['preço'].max())
print('O menor valor é:', df['preço'].min())
print('A contagem valor é:', df['preço'].count())
# Out:
# O valor total é: 295035000
# A média dos valores é: 264131.6025067144
# O Maior valor é: 384300
# O menor valor é: 145100
# A contagem valor é: 1117

# %%
# traz todas as colunas

df.describe()
# Out:
#                                 Data         area        dorms        garag  \
# count                           1117  1117.000000  1117.000000  1117.000000
# mean   2008-06-24 03:30:08.057296384   125.965085     2.523724     1.646374
# min              2005-10-08 00:00:00    25.000000     1.000000     0.000000
# 25%              2007-01-29 00:00:00    82.000000     2.000000     1.000000
# 50%              2008-06-08 00:00:00   127.000000     3.000000     2.000000
# 75%              2009-11-30 00:00:00   169.500000     3.000000     3.000000
# max              2011-03-28 00:00:00   245.000000     4.000000     4.000000
# std                              NaN    53.290147     1.106603     1.233972
#
#                preço     comissão
# count    1117.000000  1117.000000
# mean   264131.602507  3961.974038
# min    145100.000000  2176.500000
# 25%    213500.000000  3202.500000
# 50%    284300.000000  4264.500000
# 75%    314700.000000  4720.500000
# max    384300.000000  5764.500000
# ...

# %% [markdown]
# ### j). Crie um programa para criar um dataframe para mostrar as vendas por região, e salvar um arquivo em Excel para cada região.

# %%
# Filtrar um dataframe

df[df['filial'] == 'Norte']
# Out:
#      filial     vendedor       Data         tipo   area  dorms  garag piscina  \
# 2     Norte      Roberto 2005-10-12         Casa  145.5      2      2     Não
# 10    Norte     Cristina 2005-10-30  Apartamento  136.5      3      1     Não
# 19    Norte       Simone 2005-11-11  Apartamento  137.0      3      1     Sim
# 20    Norte      Roberto 2005-11-12         Casa  197.5      4      3     Sim
# 35    Norte  João Carlos 2005-12-17  Apartamento  190.5      4      4     Sim
# ...     ...          ...        ...          ...    ...    ...    ...     ...
# 1097  Norte       Simone 2011-02-22         Casa   40.0      1      0     Não
# 1098  Norte       Simone 2011-02-23         Casa  139.5      2      2     Sim
# 1106  Norte       Simone 2011-03-09  Apartamento  144.5      3      2     Sim
# 1110  Norte     Cristina 2011-03-17  Apartamento  102.5      2      0     Não
# 1114  Norte  João Carlos 2011-03-21  Apartamento  192.0      4      4     Não
#
#        preço  comissão
# ...

# %%
# filtrar um dataframe
df_norte = df[df['filial'] == 'Norte'] 

# Diretorio de destino para salvar o arquivo
pasta_destino = 'C:\\Users\\FIC\Documents\\Fabiana Python\\003 - Arquivos\\Imobiliaria_resultados\\'

# nome do arquivo
nome_arquivo = 'Norte.xlsx'

# Salvar o arquivo em excel

df_norte.to_excel(pasta_destino + nome_arquivo)

# %%
# Filtrar um dataframe - Sul

df_sul = df[df['filial'] == 'Sul'] 

pasta_destino = 'C:\\Users\\FIC\\Documents\\Fabiana Python\\003 - Arquivos\\Imobiliaria_resultados\\'

nome_arquivo = 'sul.xlsx'

df_sul.to_excel(pasta_destino + nome_arquivo)

# %%
# Filtrar um dataframe - Centro

df_Centro = df[df['filial'] == 'Centro']

pasta_destino = 'C:\\Users\\FIC\\Documents\\Fabiana Python\\003 - Arquivos\\Imobiliaria_resultados\\'

nome_arquivo = 'Centro.xlsx'

df_Centro.to_excel(pasta_destino + nome_arquivo)

# %%
# Filtrar um dataframe - Noroeste

df_Noroeste = df[df['filial']== 'Noroeste']

pasta_destino = 'C:\\Users\\FIC\\Documents\\Fabiana Python\\003 - Arquivos\\Imobiliaria_resultados\\'

nome_arquivo = 'Noroeste.xlsx'

df_Noroeste.to_excel(pasta_destino + nome_arquivo)

# %%
# Filtrar um dataframe - Sudeste

df_Sudeste = df[df['filial'] == 'Sudeste']

pasta_destino = 'C:\\Users\\FIC\\Documents\\Fabiana Python\\003 - Arquivos\\Imobiliaria_resultados\\'

nome_arquivo = 'Sudeste.xlsx'

df_Sudeste.to_excel(pasta_destino + nome_arquivo)

# %%
# Filtrar um dataframe - Oeste

df_Oeste = df[df['filial'] == 'Oeste']

pasta_destino = 'C:\\Users\\FIC\\Documents\\Fabiana Python\\003 - Arquivos\\Imobiliaria_resultados\\'

nome_arquivo = 'Oeste.xlsx'

df_Oeste.to_excel(pasta_destino + nome_arquivo)

# %%
# Filtrar um dataframe - Leste

df_Leste = df[df['filial'] == 'Leste']

pasta_destino = 'C:\\Users\\FIC\\Documents\\Fabiana Python\\003 - Arquivos\\Imobiliaria_resultados\\'

nome_arquivo = 'Leste.xlsx'

df_Leste.to_excel(pasta_destino + nome_arquivo)

# %%
# Filtrar um dataframe - Sudoeste

df_Sudoeste = df[df['filial'] == 'Sudoeste']

pasta_destino = 'C:\\Users\\FIC\\Documents\\Fabiana Python\\003 - Arquivos\\Imobiliaria_resultados\\'

nome_arquivo = 'Sudoeste.xlsx'

df_Sudoeste.to_excel(pasta_destino + nome_arquivo)

# %%
# Filtrar um dataframe - Nordeste

df_Nordeste = df[df['filial'] == 'Nordeste']

pasta_destino = 'C:\\Users\\FIC\\Documents\\Fabiana Python\\003 - Arquivos\\Imobiliaria_resultados\\'

nome_arquivo = 'Nordeste.xlsx'

df_Nordeste.to_excel(pasta_destino + nome_arquivo)

# %% [markdown]
# ### l) Gere um arquivo em Excel para representar as vendas efetuadas pela filial norte em 2010.

# %%
#ex:
df[df['Data']=='2005-10-08']
# Out:
#      filial vendedor       Data         tipo   area  dorms  garag piscina  \
# 0    Centro   Simone 2005-10-08  Apartamento  102.5      2      2     Sim
# 1  Noroeste   Simone 2005-10-08  Apartamento  199.5      4      4     Não
#
#     preço  comissão
# 0  235500    3532.5
# 1  377700    5665.5

# %%
#ex:
df[df['Data'] >'2005-10-08']
# Out:
#         filial     vendedor       Data         tipo   area  dorms  garag  \
# 2        Norte      Roberto 2005-10-12         Casa  145.5      2      2
# 3      Sudeste       Simone 2005-10-14  Apartamento  153.5      3      2
# 4     Noroeste     Cristina 2005-10-16  Apartamento   93.0      2      2
# 5        Oeste      Roberto 2005-10-17  Apartamento  124.0      3      2
# 6        Leste      Adriana 2005-10-18  Apartamento   98.5      2      1
# ...        ...          ...        ...          ...    ...    ...    ...
# 1112   Sudeste     Cristina 2011-03-19  Apartamento   87.5      2      0
# 1113   Sudeste       Simone 2011-03-20  Apartamento   74.5      2      2
# 1114     Norte  João Carlos 2011-03-21  Apartamento  192.0      4      4
# 1115     Leste       Simone 2011-03-27  Apartamento   42.0      1      1
# 1116     Oeste       Simone 2011-03-28  Apartamento  100.5      2      2
#
#      piscina   preço  comissão
# 2        Não  232500    3487.5
# ...

# %%
#ex:
#usando "entre"

df[(df['Data'] >'2005-10-14') & (df['Data']<'2005-10-17')]
# Out:
#      filial  vendedor       Data         tipo  area  dorms  garag piscina  \
# 4  Noroeste  Cristina 2005-10-16  Apartamento  93.0      2      2     Sim
#
#     preço  comissão
# 4  235400    3531.0

# %%
# l) Gere um arquivo em Excel para representar as vendas efetuadas pela filial norte em 2010.

dados = df[(df['Data']>'2010-01-01') & 
           (df['Data']<'2010-12-31') & 
           (df['filial']=='Norte')]

# nome do arquivo
nome_arquivo = 'Norte_2010.xlsx'

# Salvar o arquivo em excel

df_norte.to_excel(pasta_destino + nome_arquivo)

# %% [markdown]
# ### m) Gere um arquivo em Excel para representar as vendas efetuadas pela filial Sudeste em 2010. Sendo que no relatório deve conter apenas vendas de casas sem garagem.

# %%
dados = df[(df['Data']>'2010-01-01') & 
           (df['Data']<'2010-12-31') & 
           (df['filial']=='Sudeste') &
           (df['garag']== 0)] 


# nome do arquivo
nome_arquivo = 'Sudeste_2010.xlsx'

# Salvar o arquivo em excel

dados.to_excel(pasta_destino + nome_arquivo)

# %% [markdown]
# ### n) Qual o valor máximo de comissão que a imobiliária numa venda?

# %%
print('O Maior valor é:', df['comissão'].max())
# Out:
# O Maior valor é: 5764.5

# %%
# Retornar o registro refernte ao maior valor

df[df['comissão'] == df['comissão'].max()]
# Out:
#     filial vendedor       Data         tipo   area  dorms  garag piscina  \
# 848    Sul  Adriana 2009-12-27  Apartamento  188.5      4      4     Sim
#
#       preço  comissão
# 848  384300    5764.5

# %% [markdown]
# ### o) Quantas casas de 2 ou 3 dormitórios foram vendidas pelo Ricardo antes de 2011.

# %%
         df[(df['Data']<'2011-01-01') &
           (df['tipo']=='Casa') &
           (df['vendedor']=='Ricardo') &

           ((df['dorms']==2) |
           (df['dorms']==3))]
# Out:
#         filial vendedor       Data  tipo   area  dorms  garag piscina   preço  \
# 82       Norte  Ricardo 2006-02-28  Casa  153.0      3      3     Sim  298700
# 100      Oeste  Ricardo 2006-04-08  Casa  146.5      3      3     Sim  298300
# 156     Centro  Ricardo 2006-07-12  Casa  105.5      2      1     Não  229800
# 171      Norte  Ricardo 2006-07-27  Casa  104.0      2      1     Não  221500
# 184      Leste  Ricardo 2006-08-30  Casa  144.5      3      3     Não  307800
# 200   Noroeste  Ricardo 2006-09-25  Casa  148.5      3      3     Não  297000
# 206        Sul  Ricardo 2006-10-02  Casa  185.0      3      2     Não  287900
# 214      Leste  Ricardo 2006-10-16  Casa  149.5      3      3     Não  299600
# 251   Noroeste  Ricardo 2006-12-13  Casa  109.5      2      2     Sim  243600
# 263   Noroeste  Ricardo 2006-12-29  Casa  101.5      2      0     Não  215000
# 278   Nordeste  Ricardo 2007-01-28  Casa  124.5      2      0     Não  225400
# ...
