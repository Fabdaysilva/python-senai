# %%
import pandas as pd

# %%
# Declarar as variaveis para acessar o arquivo

path = 'C:\\Users\\FIC\\Documents\\Fabiana Python\\003 - Arquivos\\'
file = 'dados-vendas.xlsx'

# Acessar os dados do arquivo e colocar em um dataframe

dados = pd.read_excel(path + file, sheet_name='Vendas')

# %%
dados.head()
# Out:
#     ID-Produto           Produto         Categoria     Segmento  Fabricante  \
# 0  SKU-0000001   LG K10 TV Power         Celulares  Corporativo          LG
# 1  SKU-0000002  Geladeira Duplex  Eletrodomésticos    Doméstico    Brastemp
# 2  SKU-0000003    Lavadora 11 Kg  Eletrodomésticos    Doméstico    Brastemp
# 3  SKU-0000004    Lavadora 11 Kg  Eletrodomésticos    Doméstico    Brastemp
# 4  SKU-0000005    Lavadora 11 Kg  Eletrodomésticos    Doméstico  Electrolux
#
#      Loja     Cidade     Estado          Vendedor  ID-Vendedor Data Venda  \
# 0  SP8821  São Paulo  São Paulo      Ana Teixeira         1009 2012-10-04
# 1  SP8821  São Paulo  São Paulo      Josias Silva         1006 2012-01-01
# 2  SP8821  São Paulo  São Paulo      Josias Silva         1006 2012-02-02
# 3  SP8821  São Paulo  São Paulo  Mateus Gonçalves         1003 2012-03-03
# 4  SP8821  São Paulo  São Paulo     Artur Moreira         1004 2012-04-04
#
#    ValorVenda
# 0      679.00
# 1      832.00
# 2      790.00
# 3      765.32
# 4      459.89

# %%
#Seleciona apenas a coluna Vendedor e remove as duplicadas
df_estado = dados['Estado'].drop_duplicates()

# Converter o Pandas Series em uma lista
lista_estado = df_estado.tolist()

lista_estado
# Out:
# ['São Paulo',
#  'Minas Gerais',
#  'Rio de Janeiro',
#  'Espírito Santo',
#  'Paraná',
#  'Bahia']

# %%
dados[dados['Estado']== 'Paraná']
# Out:
#       ID-Produto          Produto         Categoria    Segmento Fabricante  \
# 87   SKU-0000088       Fritadeira   Eletroportáteis   Doméstico       Arno
# 89   SKU-0000090        Aspirador   Eletroportáteis   Doméstico   Britânia
# 128  SKU-0000129   Secadora Vapor  Eletrodomésticos   Doméstico   Brastemp
# 240  SKU-0000241      Micro-Ondas  Eletrodomésticos   Doméstico     Consul
# 242  SKU-0000243  Ar Condicionado  Eletrodomésticos  Industrial    Samsung
# 278  SKU-0000279       Ventilador   Eletroportáteis   Doméstico       Arno
# 281  SKU-0000282       Ventilador   Eletroportáteis   Doméstico       Arno
#
#       Loja    Cidade  Estado          Vendedor  ID-Vendedor Data Venda  \
# 87   P0761  Cascavel  Paraná     Artur Moreira         1004 2013-01-02
# 89   P0761  Cascavel  Paraná      Josias Silva         1006 2013-03-02
# 128  P0761  Cascavel  Paraná      Josias Silva         1006 2013-06-02
# 240  P0761  Cascavel  Paraná      Josias Silva         1006 2015-01-02
# 242  P0761  Cascavel  Paraná  Mateus Gonçalves         1003 2015-03-02
# 278  P0761  Cascavel  Paraná     Artur Moreira         1004 2015-03-02
# 281  P0761  Cascavel  Paraná  Rodrigo Fagundes         1005 2015-06-02
#
#      ValorVenda
# 87        297.0
# 89        167.0
# 128       799.9
# 240       290.0
# 242       455.0
# 278       123.0
# 281       134.0

# %%
# Estrutura para gerar os aruivos de forma automatica

for estado in lista_estado:
    df_final = dados[dados['Estado']== estado]
    path_New = path + 'relatorio-venda estado\\'
    # Salvar o arquivo na pasta
    df_final.to_excel(path_New + estado + '.xlsx',index = False)
